# %%
import json

# %%
import json

dictionary ={   
  "munich": '../maps/munich.graphml'
} 

with open("places.json", "w") as outfile:  
    json.dump(dictionary, outfile) 
    
# data = json.load(open('places.json'))
# data['aachen'] = 'aachen.graphml'
# with open('places.json', 'w') as outfile:
#     json.dump(data, outfile)










# json_object = json.dumps(dictionary, indent = 4)   
# print(json_object) 

# with open('data.json') as f:
#     data = json.load(f)

# with open('new_file.json', 'w') as f:
#     json.dump(data, f, indent=2)
#     print("New json file is created from data.json file")

# %%
dictionary ={   
  "aachen": 'aachen.graphml'
} 

data = json.load(open('places.json'))
data['aachen'] = 'aachen.graphml'
with open('places.json', 'w') as outfile:
    json.dump(data, outfile)


# # convert data to list if not
# if type(data) is dict:
#     data = [data]

# append new item to data lit
data['aachen'] = 'aachen.graphml'

# write list to file
with open('places.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
from pprint import pprint
json_data=open('places.json')
jdata = json.load(json_data)
pprint(jdata)
json_data.close()
# Out:
# {'aachen': 'aachen.graphml', 'munich': 'munich.graphml'}

# %%
if 'munich' in jdata:
    print('yes!')
# Out:
# yes!

# %%
print(data)
# Out:
# {'munich': 'munich.graphml'}

# %%
dictionary ={   
  "aachen": 'aachen.graphml'
} 

data = json.load(open('places.json'))
