# %%
from __future__ import print_function
from ortools.graph import pywrapgraph
import time
import os
import random as rng
import multiprocessing as mp
import numpy as np
import osmnx as ox
import matplotlib.pyplot as plt
# %matplotlib inline
ox.config(use_cache=True, log_console=True)
ox.__version__
import networkx as nx

place = 'Munich, Bavaria, Germany'
G = ox.graph_from_place(place, network_type='drive')

# %%
# ox.save_load.save_graph_osm(G, filename='munich.osm')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bb4a91adb8a5> in <module>
# ----> 1 ox.save_load.save_graph_osm(G, filename='munich.osm')
#
# AttributeError: module 'osmnx' has no attribute 'save_load'

# %%
ox.io.save_graph_xml(G, filename='munich.osm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a06eb59cc2aa> in <module>
# ----> 1 ox.io.save_graph_xml(G, filename='munich.osm')
#
# TypeError: save_graph_xml() got an unexpected keyword argument 'filename'

# %%
ox.io.save_graphml(G, filepath='maps/munich.graphml')
